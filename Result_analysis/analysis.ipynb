# %% [markdown]
# # Result Analysis

# %%
import pandas as pd
import glob
import os

# %%
folder_results = 'C:\\Users\\Emanuele\\Desktop\\Risultati Deep Learning Strokes'

architecture = 'LNN' # LSTM, GRU, RNN, VanillaRNN, Attention, LNN, XLSTM, Hierarchical Attention

folder_architecture = folder_results + '\\' + architecture

# Find all CSV files containing "results" in the name
results_files = glob.glob(folder_architecture + '\\*results*.csv')

if not results_files:
    raise FileNotFoundError(f"No CSV files with 'results' in the name found in {folder_architecture}")
elif len(results_files) > 1:
    print(f"Warning: Multiple results files found: {[os.path.basename(f) for f in results_files]}")
    print(f"Using: {os.path.basename(results_files[0])}")

# Read the CSV into a dataframe
df = pd.read_csv(results_files[0])

# %%
# group by fold and stride and get the mean of the results
df_grouped = df.groupby(['window_size', 'stride']).mean()

# sort by test accuracy
df_grouped = df_grouped.sort_values(by='test_subject_acc', ascending=False)

# drop columns that have train in the name
df_grouped = df_grouped.drop(df_grouped.columns[df_grouped.columns.str.contains('train')], axis=1)

# drop the fold column
df_grouped = df_grouped.drop('fold', axis=1)

# Save the grouped dataframe to a new CSV file in the same folder with "Test_Result" in the name
df_grouped.to_csv(folder_architecture + '\\' + "Test_Results.csv")

df_grouped
# Out:
#                     test_subject_acc  test_subject_precision  \
# window_size stride
# 20          1               0.752941                0.770941
#             2               0.735294                0.762333
# 30          1               0.729412                0.722808
#             2               0.694118                0.688597
# 10          1               0.676471                0.710185
# 50          1               0.664706                0.558502
# 20          5               0.658824                0.681097
# 60          1               0.658824                0.520286
# 10          2               0.647059                0.685197
# 2           2               0.641176                0.657723
# 5           2               0.641176                0.646289
# 2           1               0.635294                0.643442
# 5           1               0.629412                0.647567
# 20          15              0.600000                0.597252
# 10          5               0.600000                0.610818
#             10              0.600000                0.669323
# 50          2               0.594118                0.534294
# 10          15              0.588235                0.576659
# 30          5               0.582353                0.556178
# 20          10              0.582353                0.585171
# 5           5               0.576471                0.599827
# 80          1               0.576471                0.404875
# 30          10              0.564706                0.538302
# 5           15              0.558824                0.572549
# 2           10              0.541176                0.541176
# 50          5               0.541176                0.421524
# 2           5               0.541176                0.539534
# 5           10              0.535294                0.539042
# 70          1               0.535294                0.295760
# 80          5               0.529412                0.330546
# 60          2               0.523529                0.403617
#             5               0.523529                0.398384
# 30          15              0.523529                0.474946
# 2           15              0.517647                0.517647
# 60          10              0.505882                0.368308
# 50          10              0.505882                0.371644
#             15              0.500000                0.395006
# 60          15              0.500000                0.322288
# 70          2               0.488235                0.355075
# 80          2               0.488235                0.279747
# 70          10              0.470588                0.279457
#             5               0.458824                0.344958
# 80          15              0.423529                0.223633
#             10              0.394118                0.275833
# 70          15              0.388235                0.272937
#
#                     test_subject_recall  test_subject_specificity  \
# window_size stride
# 20          1                  0.869289                  0.558089
#             2                  0.841232                  0.567622
# 30          1                  0.875384                  0.549733
#             2                  0.848355                  0.513377
# 10          1                  0.809489                  0.480382
# 50          1                  0.899913                  0.534901
# 20          5                  0.787686                  0.487161
# 60          1                  0.822063                  0.585946
# 10          2                  0.793572                  0.416566
# 2           2                  0.806057                  0.442484
# 5           2                  0.768679                  0.482484
# 2           1                  0.786882                  0.446965
# 5           1                  0.789112                  0.439726
# 20          15                 0.807038                  0.425948
# 10          5                  0.751462                  0.424167
#             10                 0.672767                  0.488889
# 50          2                  0.823830                  0.455121
# 10          15                 0.855232                  0.348948
# 30          5                  0.790595                  0.394996
# 20          10                 0.775969                  0.378863
# 5           5                  0.750640                  0.356896
# 80          1                  0.811111                  0.571861
# 30          10                 0.721667                  0.469591
# 5           15                 0.923232                  0.166667
# 2           10                 0.941176                  0.058824
# 50          5                  0.825330                  0.432710
# 2           5                  0.980952                  0.057436
# 5           10                 0.798343                  0.261142
# 70          1                  0.684444                  0.520214
# 80          5                  0.594762                  0.482424
# 60          2                  0.874921                  0.392963
#             5                  0.738803                  0.433476
# 30          15                 0.622059                  0.456732
# 2           15                 1.000000                  0.000000
# 60          10                 0.746667                  0.466350
# 50          10                 0.609242                  0.430921
#             15                 0.644347                  0.438853
# 60          15                 0.734343                  0.423638
# 70          2                  0.768939                  0.428560
# 80          2                  0.600000                  0.480714
# 70          10                 0.736190                  0.447677
#             5                  0.609394                  0.429167
# 80          15                 0.707143                  0.398203
#             10                 0.671429                  0.349425
# 70          15                 0.660317                  0.392030
#
#                     test_subject_f1  test_subject_mcc  epoch
# window_size stride
# 20          1              0.815213          0.451839   40.4
#             2              0.796197          0.422196   53.6
# 30          1              0.784367          0.452817   51.6
#             2              0.753363          0.383780   36.4
# 10          1              0.752242          0.307238   56.6
# 50          1              0.671631          0.442428   26.0
# 20          5              0.724378          0.298755   37.2
# 60          1              0.616264          0.401693   36.4
# 10          2              0.731221          0.227116   41.8
# 2           2              0.715615          0.257040   29.0
# 5           2              0.697614          0.260788   40.8
# 2           1              0.701471          0.253103   29.0
# 5           1              0.704520          0.243425   37.8
# 20          15             0.650758          0.273328   30.2
# 10          5              0.671561          0.184130   35.8
#             10             0.663118          0.163114   53.0
# 50          2              0.619178          0.296893   27.6
# 10          15             0.672246          0.244557   27.8
# 30          5              0.645369          0.191407   43.2
# 20          10             0.659072          0.165054   42.8
# 5           5              0.657335          0.089808   22.4
# 80          1              0.419357          0.356798   34.4
# 30          10             0.566282          0.203251   36.8
# 5           15             0.692274          0.097458   25.4
# 2           10             0.684074          0.000000   30.0
# 50          5              0.534888          0.262317   27.0
# 2           5              0.691435          0.073953   23.0
# 5           10             0.637765          0.079707   23.4
# 70          1              0.383306          0.167943   24.2
# 80          5              0.384835          0.082830   33.0
# 60          2              0.525556          0.260216   30.6
#             5              0.492370          0.185749   27.6
# 30          15             0.507412          0.084673   27.6
# 2           15             0.680455          0.000000   22.6
# 60          10             0.426573          0.221349   21.2
# 50          10             0.425036         -0.002236   38.6
#             15             0.457235          0.102033   29.8
# 60          15             0.418971          0.157363   22.2
# 70          2              0.420509          0.198687   24.6
# 80          2              0.344845          0.084091   27.6
# 70          10             0.331640          0.175353   22.4
#             5              0.394746          0.044647   36.6
# 80          15             0.307177          0.090705   19.4
#             10             0.342147         -0.001281   36.6
# 70          15             0.291966          0.073868   29.4
